# %% [markdown]
# <a href="https://colab.research.google.com/github/sovank/DevOpsPortfolio/blob/main/Day_132_Mastering_Jenkins_Pipelines_and_Administration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q16. Set Up SCM Hook for Jenkins

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Do the step 1 its easy just follow instructions

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# \
#
# ---
#
# \

# %% [markdown]
# # Q17. Jenkins Class 3 Assignment 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# this is a problematic problem
# please dont attempt this the plugins are not working properly

# %% [markdown]
# \
#
# ---
#
# \

# %% [markdown]
# # Q18. Jenkins Class 3 Assignment 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
