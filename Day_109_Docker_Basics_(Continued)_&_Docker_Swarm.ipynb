# %% [markdown]
# <a href="https://colab.research.google.com/github/sovank/DevOpsPortfolio/blob/main/Day_109_Docker_Basics_(Continued)_%26_Docker_Swarm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q1. Managing Docker Swarm Services

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
docker swarm init

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
docker service create --name webapp --replicas 2 nginx

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
docker service scale webapp=3

# webapp is the service name of the application

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
docker service ls >> /home/user/swarm_service_output.txt
docker service ps webapp >> /home/user/swarm_service_output.txt


# cat /home/user/swarm_service_output.txt
ID             NAME      MODE         REPLICAS   IMAGE          PORTS
eosm20nsa6qo   webapp    replicated   3/3        nginx:latest
ID             NAME       IMAGE          NODE           DESIRED STATE   CURRENT STATE           ERROR     PORTS
syho92adhdqn   webapp.1   nginx:latest   3ad011c7119c   Running         Running 8 minutes ago
eudz4n1jj7c9   webapp.2   nginx:latest   3ad011c7119c   Running         Running 8 minutes ago
mqeag8bd9mch   webapp.3   nginx:latest   3ad011c7119c   Running         Running 4 minutes ago



CONTAINER ID   IMAGE          COMMAND                  CREATED          STATUS          PORTS     NAMES
6506d6e3c6b1   nginx:latest   "/docker-entrypoint.…"   7 minutes ago    Up 7 minutes    80/tcp    webapp.3.mqeag8bd9mchcvd5uhwjh2jl6
1ec6b1848bcd   nginx:latest   "/docker-entrypoint.…"   10 minutes ago   Up 10 minutes   80/tcp    webapp.2.eudz4n1jj7c9xmz8liani0b42
fe421f9916d8   nginx:latest   "/docker-entrypoint.…"   10 minutes ago   Up 10 minutes   80/tcp    webapp.1.syho92adhdqns18mtdcwj3afq
